# %% [markdown]
# # Agent Tool-Call Web Research
#
# Give an agent an annotated search function so it can retrieve web results before writing its summary.

# %% [markdown]
# ## 1. Install dependencies

# %%
# %pip install -q openai-agents ddgs
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 1.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.4/169.4 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 27.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 38.5 MB/s eta 0:00:00

# %% [markdown]
# ## 2. Choose a model provider
#
# Set `PROVIDER` to `"openai"` or `"gemini"`, then add the corresponding API key to Colab Secrets.

# %%
import os

from agents import OpenAIChatCompletionsModel, set_tracing_disabled
from google.colab import userdata
from openai import AsyncOpenAI

PROVIDER = "gemini"  # Change to "openai" to use OpenAI.
OPENAI_MODEL_NAME = "gpt-5-mini"
GEMINI_MODEL_NAME = "gemini-3.8-flash"

if PROVIDER == "openai":
    os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
    if not os.environ["OPENAI_API_KEY"]:
        raise ValueError("Add OPENAI_API_KEY to Colab Secrets.")
    model = OPENAI_MODEL_NAME
elif PROVIDER == "gemini":
    GEMINI_API_KEY = userdata.get("GeminiAPIKey")
    if not GEMINI_API_KEY:
        raise ValueError("Add GEMINI_API_KEY to Colab Secrets.")
    set_tracing_disabled(disabled=True)
    model = OpenAIChatCompletionsModel(
        model=GEMINI_MODEL_NAME,
        openai_client=AsyncOpenAI(
            base_url="https://generativelanguage.googleapis.com/v1beta/openai/",
            api_key=GEMINI_API_KEY,
        ),
    )
else:
    raise ValueError("PROVIDER must be 'openai' or 'gemini'.")

# %% [markdown]
# ## 3. Define the agent tool
#
# The `@function_tool` annotation makes `search_web` available for the agent to call.

# %%
from agents import function_tool
from ddgs import DDGS
from ddgs.exceptions import DDGSException


@function_tool
def search_web(query: str) -> str:
    """Search the web and return source titles, summaries, and URLs."""
    try:
        results = DDGS(timeout=15).text(query, max_results=5)
    except DDGSException as error:
        print(f"Search failed: {error}")
        return "Search is temporarily unavailable."

    print(f"Search query: {query}")
    print(f"Results found: {len(results)}")
    for index, result in enumerate(results, start=1):
        print(f"\n{index}. {result.get('title', 'Untitled source')}")
        print(result.get('body', 'No summary available.'))
        print(result.get('href', 'No URL available.'))

    return "\n\n".join(
        f"{result.get('title', 'Untitled source')}\n{result.get('body', '')}\n{result.get('href', '')}"
        for result in results
    )


@function_tool
def print_completion_message() -> str:
    """Print a message when research is complete and the final answer is ready."""
    message = "Research complete. Preparing the final answer."
    print(message)
    return message

# %% [markdown]
# ## 4. Let the agent search and summarize

# %%
from agents import Agent, Runner

agent = Agent(
    name="Research Assistant",
    instructions=(
        "Always call search_web before answering. After you have gathered the research, "
        "call print_completion_message immediately before your final answer. Summarize only "
        "the search results and end with a Sources section containing the URLs you used."
    ),
    tools=[search_web, print_completion_message],
    model=model,
)

question = "What is agentic AI, and how is it used in business?"
result = await Runner.run(starting_agent=agent, input=question)

print(result.final_output)
# Out:
# Search query: what is agentic AI definition business use cases
# Results found: 5
#
# 1. Agentic AI, explained - MIT Sloan
# The age of agentic AI — systems that are semi- or fully autonomous and can act on their own — has arrived. Here's what you need to know, according to MIT experts.
# https://mitsloan.mit.edu/ideas-made-to-matter/agentic-ai-explained
#
# 2. What Is Agentic AI? Definition, 6 Levels & Examples (2026)
# Agentic AI acts on its own — planning, using tools, and adapting until a task is done. Learn how it differs from chatbots, the 6 levels of autonomy, and real tools to try.
# https://agentic.ai/what-is-agentic-ai
#
# 3. What Is Agentic AI? Definition, Benefits, Use Cases - domo.com
# Learn what agentic AI is and how autonomous agents plan, use tools, and stay governed. Get benefits, use cases, risks, and agentic AI vs generative AI.
# https://www.domo.com/blog/agentic-ai-explained-definition-benefits-and-use-cases
#
# 4. What is Agentic AI? Meaning, Use Cases & How It Works (2026)
# From IT automation and compliance checks to improving supply chain coordination, Agentic AI for business process orchestration is becoming a key lever for large-scale transformation. 44% of organizations say that AI for process optimization is the most important use case. Let's unpack how Agentic AI orchestrates complex workflows.
# https://www.kore.ai/blog/what-is-agentic-ai
#
# 5. Agentic AI Use Cases: 20 Real-World Business Applications in 2026
# Explore 20 real-world agentic AI use cases across industries in 2026. Covers customer service, finance, supply chain, healthcare, IT, and more with real company examples.
# https://www.eicta.iitk.ac.in/knowledge-hub/artificial-intelligence/agentic-ai-use-cases
# Search query: MIT Sloan agentic AI explained
# Results found: 5
#
# 1. Agentic AI, explained | MIT Sloan
# February 23, 2026 - MIT Sloan professor Kate Kellogg and her co-researchers further explain in a 2025 paper that AI agents enhance large language models and similar generalist AI models by enabling them to automate complex procedures.
# https://mitsloan.mit.edu/ideas-made-to-matter/agentic-ai-explained
#
# 2. Take the MIT Agentic AI short course online.
# June 21, 2026 - This online MIT Agentic AI course offers a practical approach to deploying AI agents in your organization, including a custom playbook. 3 weeks, exclusive launch price.
# https://www.getsmarter.com/products/mit-sloan-implementing-agentic-ai-program
#
# 3. Agentic AI, explained - MIT Sloan — The Agent Times
# February 27, 2026 - The MIT Sloan analysis defines agentic AI as systems capable of autonomously perceiving their environment, making decisions, and taking actions to achieve specific goals — a sharp departure from less autonomous AI, which waits around for human ...
# https://theagenttimes.com/articles/agentic-ai-explained-mit-sloan
#
# 4. 2027 MIT Sloan Implementing Agentic AI Course Review | Research.com
# 1 month ago - Key benefits of this program include practical training on designing explainable and reliable agents, integrating AI with legacy systems, and fostering autonomy and collaboration among agents to solve complex business problems beyond traditional AI capabilities. Graduates of the 2026 MIT Sloan ...
# https://research.com/online-courses/artificial-intelligence/mit-sloan-implementing-agentic-ai-course-review
#
# 5. Agentic AI: What Leaders Wish They Knew Sooner | MIT Sloan Management Review
# June 11, 2026 - He warned that human-in-the-loop oversight of AI tools is becoming performative: “People are being pestered to approve things rapidly, so they don’t really have a chance to engage.” He worries that most humans simply won’t want to serve as auditors of what AI is doing and asserts that no amount of policy will easily fix that. George Westerman, a principal research scientist and senior lecturer at the MIT Sloan School of Management, said that agents “are not really ready for prime time in most organizations.” He noted that the word agent is being slapped on things that aren’t that sophisticated yet — inflating expectations without delivering value.
# https://sloanreview.mit.edu/video/agentic-ai-what-leaders-wish-they-knew-sooner/
# Search query: agentic AI enterprise business use cases examples
# Results found: 5
#
# 1. 10 Agentic AI Marketing Use Cases for Enterprises
# August 10, 2026 - Explore 10 agentic AI use cases for enterprises in 2026, including marketing automation, personalization, churn prediction, and campaign optimization.
# https://insiderone.com/agentic-ai-use-cases-enterprises/
#
# 2. Agentic AI Use Cases That Prove the Power of Intelligent ...
# December 5, 2025 - Agentic AI has rapidly evolved beyond traditional chatbots, enabling autonomous, multi-step workflow execution across enterprise systems. The highest-impact use cases share common traits: repetitive processes, clear policies, cross-system dependencies, and measurable business outcomes.
# https://www.moveworks.com/us/en/resources/blog/agentic-ai-examples-use-cases
#
# 3. Agentic AI Examples: 6 Enterprise Use Cases Delivering ROI | HSO
# June 11, 2026 - Customer service teams were some of the first enterprise functions to deploy AI agents at scale, and the distance between a static chatbot and an agent that can reason, retrieve, and route is now where the commercial outcomes diverge. Chatbots answer FAQs from a fixed decision tree; agentic agents read context, pull live data, apply business logic, and determine the right action. The HSO Customer Service Agent routes, categorizes, and progresses support cases using live CRM context, applying consistent logic to every case, regardless of who picks it up.
# https://www.hso.com/blog/agentic-ai-examples/
#
# 4. 10 Agentic AI Examples and Use Cases - Boomi
# December 15, 2025 - Integration Architecture Pre-built connectors to enterprise applications eliminate custom development work and allow AI agents to access data from CRM, ERP, and other business systems immediately.
# https://boomi.com/blog/10-agentic-ai-use-cases/
#
# 5. 10+ Agentic AI Use Cases to Transform Your Business | Hyland
# Explore real-world agentic AI use cases across healthcare, finance, HR and more. See how AI agents can automate workflows, lower costs and accelerate business growth.
# https://www.hyland.com/en/resources/articles/agentic-ai-use-cases
# Research complete. Preparing the final answer.
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipykernel_3589/1396108413.py in <cell line: 1>()
#      13
#      14 question = "What is agentic AI, and how is it used in business?"
# ---> 15 result = await Runner.run(starting_agent=agent, input=question)
#      16
#      17 print(result.final_output)
#
# /usr/local/lib/python3.13/dist-packages/agents/run.py in run(cls, starting_agent, input, context, max_turns, hooks, run_config, error_handlers, previous_response_id, auto_previous_response_id, conversation_id, session)
#     330         redacted_error: BaseException | None = None
#     331         try:
# --> 332             return await runner.run(
#     333                 starting_agent,
#     334                 input,
#
# /usr/local/lib/python3.13/dist-packages/agents/run.py in run(self, starting_agent, input, **kwargs)
#     563         try:
#     564             try:
# --> 565                 return await self._run_impl(starting_agent, input, **kwargs)
#     566             except BaseException as error:
#     567                 if not _is_error_data_redacted(error):
#
# /usr/local/lib/python3.13/dist-packages/agents/run.py in _run_impl(self, starting_agent, input, **kwargs)
#    1772                                 turn_result = await model_task
#    1773                         else:
# -> 1774                             turn_result = await run_single_turn(
#    1775                                 bindings=current_bindings,
#    1776                                 all_tools=all_tools,
#
# /usr/local/lib/python3.13/dist-packages/agents/run_internal/run_loop.py in run_single_turn(bindings, all_tools, original_input, generated_items, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, server_conversation_tracker, session, session_items_to_rewind, reasoning_item_id_policy, prompt_cache_key_resolver, error_handlers, agent_span, on_response_accepted, on_response_hooks_started, run_state)
#    2482         input = _prepare_turn_input_items(original_input, generated_items, reasoning_item_id_policy)
#    2483
# -> 2484     new_response = await get_new_response(
#    2485         bindings,
#    2486         system_prompt,
#
# /usr/local/lib/python3.13/dist-packages/agents/run_internal/run_loop.py in get_new_response(bindings, system_prompt, input, output_schema, all_tools, handoffs, hooks, context_wrapper, run_config, tool_use_tracker, server_conversation_tracker, prompt_config, session, session_items_to_rewind, prompt_cache_key_resolver, defer_llm_end_hooks)
#    2636
#    2637     with model_run_context(tool_use_tracker):
# -> 2638         new_response = await get_response_with_retry(
#    2639             get_response=lambda: model.get_response(
#    2640                 system_instructions=filtered.instructions,
#
# /usr/local/lib/python3.13/dist-packages/agents/run_internal/model_retry.py in get_response_with_retry(get_response, rewind, retry_settings, get_retry_advice, previous_response_id, conversation_id, timeout, replay_unsafe_request)
#     610                 websocket_pre_event_retries_disabled(disable_websocket_pre_event_retry),
#     611             ):
# --> 612                 response = await _await_model_attempt(get_response(), timeout)
#     613             response.usage = apply_retry_attempt_usage(
#     614                 response.usage,
#
# /usr/local/lib/python3.13/dist-packages/agents/run_internal/model_retry.py in _await_model_attempt(awaitable, timeout, timeout_error_seconds)
#     294     """Await one model operation and turn only this deadline into a timeout error."""
#     295     if timeout is None:
# --> 296         return await awaitable
#     297
#     298     task = asyncio.ensure_future(awaitable)
#
# /usr/local/lib/python3.13/dist-packages/agents/models/openai_chatcompletions.py in get_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, tracing, previous_response_id, conversation_id, prompt)
#     245             ),
#     246         ):
# --> 247             response = await self._fetch_response(
#     248                 system_instructions,
#     249                 input,
#
# /usr/local/lib/python3.13/dist-packages/agents/models/openai_chatcompletions.py in _fetch_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, span, tracing, stream, prompt)
#     735         create_kwargs.update(model_settings.extra_args or {})
#     736
# --> 737         ret = await self._get_client().chat.completions.create(**create_kwargs)
#     738
#     739         if isinstance(ret, ChatCompletion):
#
# /usr/local/lib/python3.13/dist-packages/openai/resources/chat/completions/completions.py in create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    2929     ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#    2930         validate_response_format(response_format)
# -> 2931         return await self._post(
#    2932             "/chat/completions",
#    2933             body=await async_maybe_transform(
#
# /usr/local/lib/python3.13/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1977             method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1978         )
# -> 1979         return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#    1980
#    1981     async def patch(
#
# /usr/local/lib/python3.13/dist-packages/openai/_base_client.py in request(self, cast_to, options, stream, stream_cls)
#    1762
#    1763                 log.debug("Re-raising status error")
# -> 1764                 raise self._make_status_error_from_response(err.response) from None
#    1765
#    1766             break
#
# RateLimitError: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-3.8-flash\nPlease retry in 44.234746308s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-3.8-flash', 'location': 'global'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '44s'}]}}]
